# %% [markdown]
# # Car Price Prediction

# %%
import pandas as pd
import selenium
from selenium import webdriver
import time
import re
import requests
from selenium.common.exceptions import NoSuchElementException

import warnings
warnings.filterwarnings("ignore")

# %%
driver=webdriver.Chrome(r'C:\Users\lenovo\Downloads\chromedriver_win32 (4)\chromedriver.exe')

# %%
url='https://www.cars24.com/buy-used-cars-new-delhi/?itm_source=Cars24Website&itm_medium=sticky_header'
driver.get(url)

# %%
urls=[]
for i in driver.find_elements_by_xpath('//div[@class="col-4"]/a'):
    urls.append(i.get_attribute('href'))

# %%
urls
# Out:
# ['https://www.cars24.com/buy-used-Toyota-Fortuner-2013-cars-New-Delhi-1009369740/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-Dzire-2012-cars-New-Delhi-1003953321/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-Dzire-2013-cars-Noida-1007895707/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-2015-cars-Noida-1012297945/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-2015-cars-New-Delhi-1105476622/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-2015-cars-Faridabad-1123533341/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-2013-cars-Noida-1051759846/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-2014-cars-Noida-1002692601/',
#  'https://www.cars24.com/buy-used-Hyundai-Elite-i20-2016-cars-Noida-1004651005/',
#  'https://www.cars24.com/buy-used-Honda-Amaze-2015-cars-New-Delhi-1006956223/',
#  'https://www.cars24.com/buy-used-Maruti-Swift-2015-cars-Noida-1159384232/',
#  'https://www.cars24.com/buy-used-Maruti-Eeco-2018-cars-Noida-1016942709/',
# ...

# %%
len(urls)
# Out:
# 144

# %%
Brand = []
Model = []
Type = []
Owner = []
KMeter = []
Fuel = []
Year_of_purchase = []
Price = []
#No_ratings = []
        
for i in urls:
    driver.get(i)
    time.sleep(3)
    
    try:
        brand = driver.find_element_by_xpath('(//h2[@class="_2geSF"]')
        Brand.append(brand.text)
    except:
        Brand.append("--")
    try:
        model = driver.find_element_by_xpath('//h2[@class="_2geSF"]/span')
        Model.append(model.text)
    except:
        Model.append("--")
    try:
        type1 = driver.find_element_by_xpath('//h2[@class="_2geSF"]/span/small')
        Type.append(type1.text)
    except:
         Type.append("--")

    try:
        owner= driver.find_element_by_xpath('//li[@class="tHlIu"][2]/strong')
        Owner.append(owner.text)
    except:
        Owner.append("--")
    try:
        km = driver.find_element_by_xpath('//li[@class="tHlIu"][3]/strong')
        KMeter.append(km.text)
    except:
        KMeter.append("--")
    try:
        fuel= driver.find_element_by_xpath('//li[@class="tHlIu"][4]/strong')
        Fuel.append(fuel.text)
    except:
        Fuel.append("--")
    try:
        year= driver.find_element_by_xpath('//li[@class="tHlIu"][9]/strong')
        Year_of_purchase.append(year.text)
    except:
        Year_of_purchase.append("--")
    try:
        price= driver.find_element_by_xpath('//div[@class="text-right _1Bt4U"]/strong/span')
        Price.append(price.text)
    except:
        Price.append("--")

# %%
len(Brand)
# Out:
# 144

# %%
len(Model)
# Out:
# 144

# %%
len(Type)
# Out:
# 144

# %%
len(Owner)
# Out:
# 144

# %%
len(KMeter)
# Out:
# 144

# %%
len(Fuel)
# Out:
# 144

# %%
len(Year_of_purchase)
# Out:
# 144

# %%
len(Price)
# Out:
# 144

# %%
Location = []
        
for i in urls:
    driver.get(i)
    time.sleep(3)
    
    try:
        loc = driver.find_element_by_xpath('//p[@class="_1OR7d"]/label')
        Location.append(loc.text)
    except:
        Location.append("--")

# %%
len(Location)
# Out:
# 144

# %%
Brand = []
Price=[]
Location=[]


for i in urls:
    driver.get(i)
    time.sleep(3)
    
    try:
        brand = driver.find_element_by_xpath('//h2[@class="_2geSF"]')
        Brand.append(brand.text)
    except:
        Brand.append("--")
        
    try:
        price= driver.find_element_by_xpath('//strong[@class="_2QqSW"]')
        Price.append(price.text)
    except:
        Price.append("--")    
        
        
        
    try:
        loc = driver.find_element_by_xpath('//p[@class="_2NHUv"]/span')
        Location.append(loc.text)
    except:
        Location.append("--")

# %%
Price=[]
Location=[]


for i in urls:
    driver.get(i)
    time.sleep(3)

    try:
        price= driver.find_element_by_xpath('//strong[@class="_2QqSW"]')
        Price.append(price.text)
    except:
        Price.append("--")    
        
        
        
    try:
        loc = driver.find_element_by_xpath('//p[@class="_2NHUv"]/span')
        Location.append(loc.text)
    except:
        Location.append("--")

# %%
print(Brand)
# Out:
# ['2013 Toyota Fortuner 3.0 AT 4X2 AUTOMATIC', '2012 Maruti Swift Dzire VDI BS IV MANUAL', '2013 Maruti Swift Dzire VDI BS IV MANUAL', '2015 Maruti Swift LDI BS IV MANUAL', '2015 Maruti Swift VDI ABS MANUAL', '2015 Maruti Swift VDI ABS MANUAL', '2013 Maruti Swift VDI MANUAL', '2014 Maruti Swift VDI MANUAL', '2016 Hyundai Elite i20 SPORTZ 1.2 MANUAL', '2015 Honda Amaze 1.2 SMT I VTEC MANUAL', '2015 Maruti Swift VDI ABS MANUAL', '2018 Maruti Eeco 7 STR MANUAL', '2017 Maruti Baleno DELTA 1.2 K12 MANUAL', '2018 Datsun Redi Go 1.0 S AT', '2018 Maruti Vitara Brezza VDI OPT MANUAL', '2020 Maruti Baleno DELTA 1.2 K12 MANUAL', '2017 Maruti Vitara Brezza VDI OPT MANUAL', '2017 Maruti Alto 800 LXI MANUAL', '2018 Maruti Vitara Brezza VDI MANUAL', '2019 Maruti Celerio VXI MANUAL', '2019 Maruti XL6 ALPHA SHVS MT MANUAL', '2015 Hyundai Creta 1.6 S MANUAL', '2019 Maruti Baleno DELTA 1.2 K12 MANUAL', '2017 Volkswagen Ameo TRENDLINE 1.2 MANUAL', '2013 Ford Ecosport 1.5TITANIUM TDCI MANUAL', '2012 Toyot
# ...

# %%
print(Model)
# Out:
# ['3.0 AT 4X2 AUTOMATIC', 'VDI BS IV MANUAL', 'VDI BS IV MANUAL', 'LDI BS IV MANUAL', 'VDI ABS MANUAL', 'VDI ABS MANUAL', 'VDI MANUAL', 'VDI MANUAL', 'SPORTZ 1.2 MANUAL', '1.2 SMT I VTEC MANUAL', 'VDI ABS MANUAL', '7 STR MANUAL', 'DELTA 1.2 K12 MANUAL', '1.0 S AT', 'VDI OPT MANUAL', 'DELTA 1.2 K12 MANUAL', 'VDI OPT MANUAL', 'LXI MANUAL', 'VDI MANUAL', 'VXI MANUAL', 'ALPHA SHVS MT MANUAL', '1.6 S MANUAL', 'DELTA 1.2 K12 MANUAL', 'TRENDLINE 1.2 MANUAL', '1.5TITANIUM TDCI MANUAL', '3.0 MT 4X4 MANUAL', 'SPORTS 1.2 VTVT MANUAL', 'VDI OPT MANUAL', 'ZDI MANUAL', 'ZDI MANUAL', '1.6 SX PLUS DIESEL MANUAL', 'VDI PLUS MANUAL', 'E200 CGI EDITION E MANUAL', 'LDI BS IV MANUAL', 'DELTA 1.5 SHVS VVT MT MANUAL', 'VDI OPT MANUAL', 'VDI OPT MANUAL', 'ALPHA SHVS MANUAL', '1.5TITANIUM TDCI MANUAL', '1.5TITANIUM TDCI MANUAL', '1.5 TITANIUMTDCI OPT MANUAL', '1.5 TDCI TITANIUM PLUS MANUAL', 'XT 1.2 REVOTRON MANUAL', 'ZDI AMT AUTOMATIC', 'VDI OPT MANUAL', 'VDI OPT MANUAL', 'VDI MANUAL', 'VDI OPT MANUAL', '1.2
# ...

# %%
print(Price)
# Out:
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '--', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '--', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']

# %%
print(Location)
# Out:
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '--', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '--', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']

# %%
len(Location)
# Out:
# 144

# %%
df1 = pd.DataFrame({})
df1["Brand"] = Brand
df1["Model"] = Model
df1["Type"] = Type
df1["Owner"] = Owner
df1["KMeter"] = KMeter
df1["Fuel"] = Fuel
df1["Price"] = Price
df1["Location"] = Location

df1
# Out:
#                                          Brand                 Model  \
# 0    2013 Toyota Fortuner 3.0 AT 4X2 AUTOMATIC  3.0 AT 4X2 AUTOMATIC
# 1     2012 Maruti Swift Dzire VDI BS IV MANUAL      VDI BS IV MANUAL
# 2     2013 Maruti Swift Dzire VDI BS IV MANUAL      VDI BS IV MANUAL
# 3           2015 Maruti Swift LDI BS IV MANUAL      LDI BS IV MANUAL
# 4             2015 Maruti Swift VDI ABS MANUAL        VDI ABS MANUAL
# ..                                         ...                   ...
# 139            2019 Maruti Alto K10 VXI MANUAL            VXI MANUAL
# 140               2019 Maruti Swift VXI MANUAL            VXI MANUAL
# 141               2019 Maruti Dzire VDI MANUAL            VDI MANUAL
# 142               2016 Maruti Swift ZDI MANUAL            ZDI MANUAL
# 143               2014 Maruti Swift ZDI MANUAL            ZDI MANUAL
#
#           Type      Owner       KMeter    Fuel Price Location
# 0    AUTOMATIC  1st Owner    74,189 km  Diesel
# ...

# %%
url0='https://www.cars24.com/buy-used-cars-noida/?itm_source=Cars24Website&itm_medium=sticky_header'
driver.get(url0)

# %%
urls0=[]
for i in driver.find_elements_by_xpath('//div[@class="col-4"]/a'):
    urls0.append(i.get_attribute('href'))

# %%
len(urls0)
# Out:
# 143

# %%
Brand1 = []
Model1 = []
Type1 = []
Owner1 = []
KMeter1 = []
Fuel1 = []
Year_of_purchase1 = []
Price1 = []
Location1 = []
        
for i in urls0:
    driver.get(i)
    time.sleep(3)
    
    try:
        brand1 = driver.find_element_by_xpath('//h2[@class="_2geSF"]')
        Brand1.append(brand1.text)
    except:
        Brand1.append("--")
    try:
        model1 = driver.find_element_by_xpath('//h2[@class="_2geSF"]/span')
        Model1.append(model1.text)
    except:
        Model1.append("--")
    try:
        type11 = driver.find_element_by_xpath('//h2[@class="_2geSF"]/span/small')
        Type1.append(type11.text)
    except:
         Type1.append("--")

    try:
        owner1= driver.find_element_by_xpath('//li[@class="tHlIu"][2]/strong')
        Owner1.append(owner1.text)
    except:
        Owner1.append("--")
    try:
        km1 = driver.find_element_by_xpath('//li[@class="tHlIu"][3]/strong')
        KMeter1.append(km1.text)
    except:
        KMeter1.append("--")
    try:
        fuel1= driver.find_element_by_xpath('//li[@class="tHlIu"][4]/strong')
        Fuel1.append(fuel1.text)
    except:
        Fuel1.append("--")
    try:
        year1= driver.find_element_by_xpath('//li[@class="tHlIu"][9]/strong')
        Year_of_purchase1.append(year1.text)
    except:
        Year_of_purchase1.append("--")
    try:
        price1= driver.find_element_by_xpath('//div[@class="text-right _1Bt4U"]/strong/span')
        Price1.append(price1.text)
    except:
        Price1.append("--")
    try:
        loc1 = driver.find_element_by_xpath('//p[@class="_2NHUv"]/span')
        Location1.append(loc1.text)
    except:
        Location1.append("--")

# %%
df2 = pd.DataFrame({})
df2["Brand"] = Brand
df2["Model"] = Model
df2["Type"] = Type
df2["Owner"] = Owner
df2["KMeter"] = KMeter
df2["Fuel"] = Fuel
df2["Price"] = Price
df2["Location"] = Location

df2
# Out:
#                                          Brand                 Model  \
# 0    2013 Toyota Fortuner 3.0 AT 4X2 AUTOMATIC  3.0 AT 4X2 AUTOMATIC
# 1     2012 Maruti Swift Dzire VDI BS IV MANUAL      VDI BS IV MANUAL
# 2     2013 Maruti Swift Dzire VDI BS IV MANUAL      VDI BS IV MANUAL
# 3           2015 Maruti Swift LDI BS IV MANUAL      LDI BS IV MANUAL
# 4             2015 Maruti Swift VDI ABS MANUAL        VDI ABS MANUAL
# ..                                         ...                   ...
# 139            2019 Maruti Alto K10 VXI MANUAL            VXI MANUAL
# 140               2019 Maruti Swift VXI MANUAL            VXI MANUAL
# 141               2019 Maruti Dzire VDI MANUAL            VDI MANUAL
# 142               2016 Maruti Swift ZDI MANUAL            ZDI MANUAL
# 143               2014 Maruti Swift ZDI MANUAL            ZDI MANUAL
#
#           Type      Owner       KMeter    Fuel Price Location
# 0    AUTOMATIC  1st Owner    74,189 km  Diesel
# ...

# %%
df1.append(df2, ignore_index=True)0

# %% [markdown]
# # Web scrapping of Used Car

# %%
url1='https://www.cardekho.com/used-cars+in+ahmedabad'
driver.get(url1)

# %%
brand=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/a')
brand


#now the text of the job title is inside the tag is extracted above.
# so we run for loop  to extract data
Brand=[]
for i in brand:
    Brand.append(i.text)

#job_titles=job_titles[:10]
Brand
# Out:
# ['2016 Maruti Eeco',
#  '2018 Volkswagen Vento',
#  '2017 Honda Amaze',
#  '2018 Honda City',
#  '2014 Maruti Wagon R',
#  '2019 Maruti Swift Dzire',
#  '2013 Toyota Innova',
#  '2016 Nissan Terrano',
#  '2020 Maruti Eeco',
#  '2013 Maruti Wagon R',
#  '2017 Maruti Baleno',
#  '2017 Maruti Baleno',
#  '2012 Maruti Eeco',
#  '2015 Maruti Swift Dzire',
#  '2012 Toyota Innova',
#  '2018 Maruti Swift',
#  '2014 Maruti Swift',
#  '2019 Tata Nexon',
#  '2016 Chevrolet Beat',
#  '2017 Maruti SX4 S Cross',
#  '2019 Maruti Eeco',
#  '2015 Hyundai Grand i10',
#  '2017 Maruti Wagon R',
#  '2017 Maruti Eeco',
#  '2020 Maruti Eeco',
#  '2014 Hyundai Verna',
#  '2012 Maruti Swift Dzire',
#  '2019 Maruti S-Presso',
#  '2011 Maruti Wagon R',
#  '2018 Maruti Swift',
#  '2013 Maruti Swift',
#  '2017 Maruti Wagon R',
#  '2019 Maruti Swift Dzire',
#  '2016 Maruti Swift',
#  '2016 Maruti Baleno',
#  '2012 Maruti Alto K10',
#  '2014 Maruti Wagon R',
#  '2016 Maruti Wagon R',
#  '2020 Maruti Wagon R',
# ...

# %%
len(Brand)
# Out:
# 537

# %%
varient=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/div[1]')
varient


#now the text of the job title is inside the tag is extracted above.
# so we run for loop  to extract data
Varient=[]
for i in varient:
    Varient.append(i.text)

#job_titles=job_titles[:10]
Varient
# Out:
# ['5 Seater AC BSIV',
#  '1.5 TDI Highline',
#  'S Option i-VTEC',
#  'i-VTEC V',
#  'VXI',
#  'VXI 1.2',
#  '2.5 VX (Diesel) 8 Seater',
#  'XL Plus 85 PS',
#  '5 Seater AC',
#  'LXI BS IV',
#  'Alpha',
#  'Delta',
#  '5 Seater AC',
#  'VDI',
#  '2.5 GX (Diesel) 8 Seater',
#  'AMT VDI',
#  'VDI BSIV',
#  '1.5 Revotorq XZ Plus',
#  'Diesel LT',
#  'Alpha DDiS 200 SH',
#  '5 Seater AC BSIV',
#  'Asta',
#  'VXI Plus',
#  '5 Seater AC',
#  '5 Seater AC',
#  '1.6 SX CRDi (O)',
#  'VDI',
#  'VXI',
#  'LXI BS IV',
#  'VDI',
#  'ZDi',
#  'AMT VXI',
#  'VXI 1.2',
#  'VXI Optional',
#  '1.2 Delta',
#  'LXI',
#  'VXI',
#  'VXI',
#  'LXI',
#  'VXI 1.2',
#  'LXI',
#  'Quadrajet VX',
#  'LXI BSIII',
#  'LX BSIII',
#  'Delta Diesel',
#  'LXI',
#  'DI 4X4',
#  'Magna 1.4 CRDi',
#  '1.6 SX CRDi (O)',
#  'VDI',
#  'LXI BS IV',
#  'LXi',
#  'Sportz',
#  'Diesel Comfortline',
#  '3.0 TDI Quattro Technology',
#  '2.8 ZX AT BSIV',
#  'VX i-Vtech',
#  'VDI BSIV',
#  'D-4D G',
#  'Teana',
#  'Twist XT',
# ...

# %%
len(Varient)
# Out:
# 537

# %%
km=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/div/span[1]')
km


#now the text of the job title is inside the tag is extracted above.
# so we run for loop  to extract data
KM=[]
for i in km:
    KM.append(i.text)

#job_titles=job_titles[:10]
KM
# Out:
# ['45,347 kms',
#  '97,922 kms',
#  '59,642 kms',
#  '89,144 kms',
#  '1,31,125 kms',
#  '11,935 kms',
#  '94,754 kms',
#  '74,555 kms',
#  '19,627 kms',
#  '85,416 kms',
#  '49,072 kms',
#  '34,669 kms',
#  '57,341 kms',
#  '54,419 kms',
#  '1,47,234 kms',
#  '37,383 kms',
#  '72,558 kms',
#  '60,833 kms',
#  '65,182 kms',
#  '86,698 kms',
#  '14,161 kms',
#  '73,875 kms',
#  '43,242 kms',
#  '88,362 kms',
#  '17,116 kms',
#  '65,484 kms',
#  '80,084 kms',
#  '24,230 kms',
#  '60,722 kms',
#  '31,824 kms',
#  '72,301 kms',
#  '41,174 kms',
#  '9,379 kms',
#  '45,203 kms',
#  '51,205 kms',
#  '89,579 kms',
#  '42,381 kms',
#  '81,674 kms',
#  '10,371 kms',
#  '9,718 kms',
#  '89,000 kms',
#  '1,20,000 kms',
#  '80,000 kms',
#  '58,000 kms',
#  '65,000 kms',
#  '75,863 kms',
#  '40,000 kms',
#  '45,000 kms',
#  '83,000 kms',
#  '80,000 kms',
#  '36,100 kms',
#  '65,000 kms',
#  '16,234 kms',
#  '80,000 kms',
#  '70,000 kms',
#  '68,000 kms',
#  '36,000 kms',
#  '65,000 kms',
# ...

# %%
len(KM)
# Out:
# 537

# %%
fuel=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/div/span[2]')
fuel


#now the text of the job title is inside the tag is extracted above.
# so we run for loop  to extract data
Fuel=[]
for i in fuel:
    Fuel.append(i.text)

#job_titles=job_titles[:10]
Fuel
# Out:
# ['Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
# ...

# %%
len(Fuel)
# Out:
# 537

# %%
trans=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/div/span[3]')
trans


#now the text of the job title is inside the tag is extracted above.
# so we run for loop  to extract data
Transmission=[]
for i in trans:
    Transmission.append(i.text)

#job_titles=job_titles[:10]
Transmission
# Out:
# ['Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
# ...

# %%
len(Transmission)
# Out:
# 537

# %%
price=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-5 text-right price"]/span')
price


#now the text of the job title is inside the tag is extracted above.
# so we run for loop  to extract data
Price=[]
for i in price:
    Price.append(i.text)

#job_titles=job_titles[:10]
Price
# Out:
# ['3.5 Lakh',
#  '6.99 Lakh',
#  '5.53 Lakh',
#  '7.64 Lakh',
#  '2.94 Lakh',
#  '6.8 Lakh',
#  '6.7 Lakh',
#  '4.7 Lakh',
#  '4.7 Lakh',
#  '2.8 Lakh',
#  '6.1 Lakh',
#  '5.2 Lakh',
#  '2.79 Lakh',
#  '4.85 Lakh',
#  '5.67 Lakh',
#  '5.9 Lakh',
#  '3.82 Lakh',
#  '7.81 Lakh',
#  '1.74 Lakh',
#  '6.6 Lakh',
#  '4.57 Lakh',
#  '4.7 Lakh',
#  '3.82 Lakh',
#  '3.97 Lakh',
#  '4.25 Lakh',
#  '4.7 Lakh',
#  '3.35 Lakh',
#  '3.9 Lakh',
#  '2.67 Lakh',
#  '6 Lakh',
#  '2.9 Lakh',
#  '4.25 Lakh',
#  '6.75 Lakh',
#  '4.6 Lakh',
#  '4.7 Lakh',
#  '1.65 Lakh',
#  '3.25 Lakh',
#  '3.45 Lakh',
#  '5.07 Lakh',
#  '6.45 Lakh',
#  '3.15 Lakh',
#  '1.5 Lakh',
#  '1.25 Lakh',
#  '1.7 Lakh',
#  '5.75 Lakh',
#  '2.8 Lakh',
#  '6.9 Lakh',
#  '6.5 Lakh',
#  '5.4 Lakh',
#  '3.65 Lakh',
#  '3.4 Lakh',
#  '1.6 Lakh',
#  '4.75 Lakh',
#  '3.75 Lakh',
#  '23 Lakh',
#  '22 Lakh',
#  '5.25 Lakh',
#  '4.9 Lakh',
#  '5.25 Lakh',
#  '4 Lakh',
#  '1.6 Lakh',
#  '14.25 Lakh',
#  '8.11 Lakh',
#  '6.9 Lakh',
# ...

# %%
len(Price)
# Out:
# 537

# %%
Location=[]
for i in driver.find_elements_by_xpath('//div[@class="cityIcon"]'):
    try:
        Location.append(i.text)
    except:
        Location.append("--")



Location
# Out:
# ['Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
# ...

# %%
len(Location)
# Out:
# 506

# %%
loc10 = []
loc10.extend(["nan" for i in range(31)])
loc10
# Out:
# ['nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan']

# %%
Location.extend(loc10)

# %%
len(Location)
# Out:
# 537

# %%
urls1=[]
for i in driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/a'):
    urls1.append(i.get_attribute('href'))

# %%
len(urls1)
# Out:
# 537

# %%
Owner = []
Year_of_purchase = []

for i in urls1:
    driver.get(i)
    time.sleep(3)
    
    try:
        owner= driver.find_element_by_xpath('//li[@class="gsc_col-xs-6"][4]/div/div[1]')
        Owner.append(owner.text)
    except:
        Owner.append("--")
    
    try:
        year= driver.find_element_by_xpath('//li[@class="gsc_col-xs-6"][1]/div/div[1]')
        Year_of_purchase.append(year.text)
    except:
        Year_of_purchase.append("--")

# %%
len(Owner)
# Out:
# 537

# %%
print(Owner)
# Out:
# ['--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', 'Second Owner', 'First Owner', 'Second Owner', 'First Owner', 'Second Owner', 'First Owner', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', '--', 'First Owner', 'First Owner', 'First Owner', 'First Owner', 'Second Owner', 'Second Owner', 'Second Owner', 'First Owner', 'First Owner', 'First Owner', 'First Owner', 'First Owner', 'First Owner', 'First Owner', 'Second Owner', 'First Owner', 'First Owner', 'First Owner', 'First Owner', 'First Owner', 'First Owner', 'First Owner', 'Third Owner', 'First Owner', 'Second Owner', 'First Owner', 'First Owner', 'Second Owner', 'First Owner', 'First Owner', 'First Owner', 'First Owner', 'Second Owner', 'First Owner', 'First Owner', 'First Owner', 'First Owner', 'Second Owner', 'First Owner', 'First Owner', 'Second Owner', 'Second Owner', 'First Owner', 'First Owner', 'First Owner', 'First Owner', 'First Owner', 'Fi
# ...

# %%
len(Year_of_purchase)
# Out:
# 537

# %%
df1 = pd.DataFrame({})
df1["Brand"] = Brand
df1["Varient"] = Varient
df1["Transmission"] = Transmission
df1["Owner"] = Owner
df1["KiloMeter"] = KM
df1["Fuel"] = Fuel
df1["Year_of_purchase"] = Year_of_purchase
df1["Location"] = Location
df1["Price"] = Price


df1
# Out:
#                       Brand                     Varient Transmission  \
# 0          2016 Maruti Eeco            5 Seater AC BSIV       Manual
# 1     2018 Volkswagen Vento            1.5 TDI Highline       Manual
# 2          2017 Honda Amaze             S Option i-VTEC       Manual
# 3           2018 Honda City                    i-VTEC V       Manual
# 4       2014 Maruti Wagon R                         VXI       Manual
# ..                      ...                         ...          ...
# 532         2012 Maruti SX4                         VDI       Manual
# 533      2012 Maruti Ertiga                         LDI       Manual
# 534    2013 Mahindra Quanto                          C8       Manual
# 535  2018 Hyundai Grand i10  1.2 Kappa Sportz Option AT    Automatic
# 536   2013 Mahindra Scorpio                 SLE 7S BSIV       Manual
#
#             Owner     KiloMeter    Fuel Year_of_purchase   Location      Price
# ...

# %%
df1.to_csv("Ahmadabad_data")

# %%
driver.close()

# %%
url1='https://www.cardekho.com/used-cars+in+pune'
driver.get(url1)

# %%
brand=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/a')
brand


# so we run for loop  to extract data
Brand=[]
for i in brand:
    Brand.append(i.text)


Brand
# Out:
# ['2020 Honda Amaze',
#  '2015 Honda Jazz',
#  '2020 Maruti Celerio X',
#  '2018 Maruti Vitara Brezza',
#  '2015 Hyundai Grand i10',
#  '2014 Maruti Wagon R',
#  '2017 Maruti Ignis',
#  '2017 Maruti Wagon R',
#  '2018 Maruti Vitara Brezza',
#  '2015 Maruti Wagon R',
#  '2018 Maruti Celerio',
#  '2017 Maruti Ciaz',
#  '2018 Hyundai Santro',
#  '2016 Hyundai Grand i10',
#  '2013 Hyundai Grand i10',
#  '2018 Volkswagen Passat',
#  '2015 Volkswagen Polo',
#  '2013 Ford Ecosport',
#  '2017 Mercedes-Benz E-Class',
#  '2018 Maruti Wagon R',
#  '2016 Maruti Celerio',
#  '2015 Hyundai Grand i10',
#  '2017 Maruti Ignis',
#  '2017 Maruti Wagon R',
#  '2017 Maruti Wagon R',
#  '2014 Hyundai Grand i10',
#  '2016 Maruti Celerio',
#  '2018 Maruti Celerio X',
#  '2016 Maruti Celerio',
#  '2017 Maruti Celerio',
#  '2015 Hyundai i20',
#  '2014 Maruti Wagon R',
#  '2018 Maruti Vitara Brezza',
#  '2017 Maruti Vitara Brezza',
#  '2015 Hyundai i20',
#  '2017 Honda Jazz',
#  '2018 Maruti Baleno',
# ...

# %%
len(Brand)
# Out:
# 1145

# %%
year=Brand[]
year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-90433fc259eb> in <module>
# ----> 1 year=Brand.split(' ',2)[0]
#       2 year
#
# AttributeError: 'list' object has no attribute 'split'

# %%
varient=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/div[1]')
varient


#now the text of the job title is inside the tag is extracted above.
# so we run for loop  to extract data
Varient=[]
for i in varient:
    Varient.append(i.text)

#job_titles=job_titles[:10]
Varient
# Out:
# ['VX Petrol',
#  '1.5 V i DTEC',
#  'AMT ZXI',
#  'ZDi AMT',
#  'AT Asta',
#  'VXI',
#  '1.2 Zeta BSIV',
#  'VXI Opt',
#  'ZDi AMT',
#  'VXI',
#  'ZXI Optional AMT BSIV',
#  'Alpha AT',
#  'Magna BSIV',
#  'Asta Option AT',
#  'CRDi Magna',
#  '2.0 TDI AT Highline',
#  '1.5 TDI Comfortline',
#  '1.5 DV5 MT Trend',
#  'Expression E 220d',
#  'CNG LXI',
#  'VXi AMT',
#  'CRDi Asta Option',
#  '1.2 Zeta BSIV',
#  'AMT VXI',
#  'VXI BS IV',
#  'AT Asta',
#  'ZXI AT',
#  'AMT ZXI',
#  'ZXI AT',
#  'ZXI AT',
#  'Magna 1.2',
#  'VXI BS IV',
#  'ZDi AMT',
#  'ZDi',
#  'Sportz 1.2',
#  '1.2 V AT i VTEC',
#  'Zeta CVT',
#  'ZXI AT Optional',
#  'Sigma',
#  'VDi AMT',
#  '1.3 Zeta',
#  'VXI',
#  'VXI BS IV',
#  'Asta 1.4 CRDi',
#  'ZXi',
#  'AT Asta',
#  '1.2 CVT Alpha',
#  '1.0 TSI Style',
#  'V',
#  'VXI Optional',
#  'Sportz AMT BSIV',
#  'ZXi',
#  'J CVT BSIV',
#  'VX i DTEC',
#  'VXI Plus AT',
#  'ZXI AT',
#  'Sportz 1.1L',
#  'VXI AT',
#  'ZXI AT',
#  'Titanium BSIV',
#  '1.2 CVT Zeta',
# ...

# %%
len(Varient)
# Out:
# 1145

# %%
km=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/div/span[1]')
km


#now the text of the job title is inside the tag is extracted above.
# so we run for loop  to extract data
KM=[]
for i in km:
    KM.append(i.text)

#job_titles=job_titles[:10]
KM
# Out:
# ['12,887 kms',
#  '95,199 kms',
#  '4,107 kms',
#  '34,470 kms',
#  '62,282 kms',
#  '28,181 kms',
#  '41,481 kms',
#  '43,192 kms',
#  '27,133 kms',
#  '24,152 kms',
#  '26,724 kms',
#  '43,023 kms',
#  '21,969 kms',
#  '21,444 kms',
#  '36,208 kms',
#  '60,000 kms',
#  '46,374 kms',
#  '1,06,000 kms',
#  '31,037 kms',
#  '60,000 kms',
#  '27,607 kms',
#  '50,966 kms',
#  '83,629 kms',
#  '23,604 kms',
#  '50,350 kms',
#  '86,499 kms',
#  '28,523 kms',
#  '18,124 kms',
#  '34,892 kms',
#  '30,128 kms',
#  '45,396 kms',
#  '40,670 kms',
#  '89,503 kms',
#  '78,514 kms',
#  '50,722 kms',
#  '30,383 kms',
#  '26,702 kms',
#  '14,899 kms',
#  '6,019 kms',
#  '25,449 kms',
#  '22,992 kms',
#  '29,433 kms',
#  '40,772 kms',
#  '84,414 kms',
#  '32,398 kms',
#  '54,990 kms',
#  '24,229 kms',
#  '3,381 kms',
#  '27,666 kms',
#  '34,013 kms',
#  '24,296 kms',
#  '67,959 kms',
#  '54,959 kms',
#  '10,317 kms',
#  '527 kms',
#  '10,437 kms',
#  '22,438 kms',
#  '56,370 kms',
#  '33,661 kms',
# ...

# %%
len(KM)
# Out:
# 1145

# %%
fuel=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/div/span[2]')
fuel


#now the text of the job title is inside the tag is extracted above.
# so we run for loop  to extract data
Fuel=[]
for i in fuel:
    Fuel.append(i.text)

#job_titles=job_titles[:10]
Fuel
# Out:
# ['Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'CNG',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
# ...

# %%
len(Fuel)
# Out:
# 1145

# %%
trans=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/div/span[3]')
trans


#now the text of the job title is inside the tag is extracted above.
# so we run for loop  to extract data
Transmission=[]
for i in trans:
    Transmission.append(i.text)

#job_titles=job_titles[:10]
Transmission
# Out:
# ['Manual',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
# ...

# %%
len(Transmission)
# Out:
# 1145

# %%
price=driver.find_elements_by_xpath('//div[@class="gsc_col-xs-5 text-right price"]/span')
price


#now the text of the job title is inside the tag is extracted above.
# so we run for loop  to extract data
Price=[]
for i in price:
    Price.append(i.text)

#job_titles=job_titles[:10]
len(Price)
# Out:
# 1145

# %%
Location=[]
for i in driver.find_elements_by_xpath('//div[@class="cityIcon"]'):
    try:
        Location.append(i.text)
    except:
        Location.append("--")



len(Location)
# Out:
# 1016

# %%
loc10 = []
loc10.extend(["nan" for i in range(129)])
#loc10
Location.extend(loc10)

# %%
len(Location)
# Out:
# 1145

# %%
urls2=[]
for i in driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/a'):
    urls2.append(i.get_attribute('href'))

# %%
len(urls2)
# Out:
# 1145

# %%
Owner = []
Year_of_purchase = []

for i in urls2:
    driver.get(i)
    time.sleep(3)
    
    try:
        owner= driver.find_element_by_xpath('//li[@class="gsc_col-xs-6"][4]/div/div[1]')
        Owner.append(owner.text)
    except:
        Owner.append("--")
    
    try:
        year= driver.find_element_by_xpath('//li[@class="gsc_col-xs-6"][1]/div/div[1]')
        Year_of_purchase.append(year.text)
    except:
        Year_of_purchase.append("--")

# %%
len(Owner)
# Out:
# 1145

# %%
len(Year_of_purchase)
# Out:
# 1145

# %%
df1 = pd.DataFrame({})
df1["Brand"] = Brand
df1["Varient"] = Varient
df1["Transmission"] = Transmission
df1["Owner"] = Owner
df1["KiloMeter"] = KM
df1["Fuel"] = Fuel
df1["Year_of_purchase"] = Year_of_purchase
df1["Location"] = Location
df1["Price"] = Price


df1
# Out:
#                           Brand                 Varient Transmission  \
# 0              2020 Honda Amaze               VX Petrol       Manual
# 1               2015 Honda Jazz            1.5 V i DTEC       Manual
# 2         2020 Maruti Celerio X                 AMT ZXI    Automatic
# 3     2018 Maruti Vitara Brezza                 ZDi AMT    Automatic
# 4        2015 Hyundai Grand i10                 AT Asta    Automatic
# ...                         ...                     ...          ...
# 1140         2013 Skoda Octavia     Ambition 1.8 TSI AT    Automatic
# 1141          2015 Skoda Superb  Elegance 2.0 TDI CR AT    Automatic
# 1142         2009 Toyota Innova   2.5 V Diesel 8-seater       Manual
# 1143           2011 Maruti Alto                     LXi       Manual
# 1144         2015 Hyundai Verna       1.6 VTVT S Option       Manual
#
#              Owner     KiloMeter    Fuel Year_of_purchase Location      Price
# ...

# %%
df1.to_csv("Pune_data")

# %%
driver.close()

# %%
url3='https://www.cardekho.com/used-cars+in+bangalore'
driver.get(url3)

# %%
Brand=[]
Varient=[]
KM=[]
Fuel=[]
Transmission=[]
Price=[]
Location=[]

for i in driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/a'):
    Brand.append(i.text)
    



for i in driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/div[1]'):
    Varient.append(i.text)



for i in driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/div/span[1]'):
    KM.append(i.text)






for i in driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/div/span[2]'):
    Fuel.append(i.text)


for i in driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/div/span[3]'):
    Transmission.append(i.text)



for i in driver.find_elements_by_xpath('//div[@class="gsc_col-xs-5 text-right price"]/span'):
    Price.append(i.text)





for i in driver.find_elements_by_xpath('//div[@class="cityIcon"]'):
    try:
        Location.append(i.text)
    except:
        Location.append("--")



print("Location counts:-" ,len(Location))

print("Transmission Counts:-",  len(Transmission))
print("Fuel counts:-" , len(Fuel))   

print("KM counts:-" , len(KM))
print("Price counts:-",   len(Price))
print("Varient counts:-" ,  len(Varient))

print("Brand counts:- ",    len(Brand))
# Out:
# Location counts:- 1279
# Transmission Counts:- 1736
# Fuel counts:- 1736
# KM counts:- 1736
# Price counts:- 1736
# Varient counts:- 1736
# Brand counts:-  1736

# %%
loc10 = []
loc10.extend(["nan" for i in range(457)])
#loc10
Location.extend(loc10)
len(Location)
# Out:
# 1736

# %%
urls3=[]
for i in driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/a'):
    urls3.append(i.get_attribute('href'))

# %%
len(urls3)
# Out:
# 1736

# %%
Owner = []
Year_of_purchase = []

for i in urls3:
    driver.get(i)
    time.sleep(3)
    
    try:
        owner= driver.find_element_by_xpath('//li[@class="gsc_col-xs-6"][4]/div/div[1]')
        Owner.append(owner.text)
    except:
        Owner.append("--")
    
    try:
        year= driver.find_element_by_xpath('//li[@class="gsc_col-xs-6"][1]/div/div[1]')
        Year_of_purchase.append(year.text)
    except:
        Year_of_purchase.append("--")

# %%
len(Owner)
# Out:
# 1736

# %%
len(Year_of_purchase)
# Out:
# 1736

# %%
df1 = pd.DataFrame({})
df1["Brand"] = Brand
df1["Varient"] = Varient
df1["Transmission"] = Transmission
df1["Owner"] = Owner
df1["KiloMeter"] = KM
df1["Fuel"] = Fuel
df1["Year_of_purchase"] = Year_of_purchase
df1["Location"] = Location
df1["Price"] = Price


df1
# Out:
#                        Brand                     Varient Transmission  \
# 0           2013 Hyundai i10                      Sportz       Manual
# 1           2011 Hyundai i10                      Sportz       Manual
# 2          2018 Renault KWID                 1.0 RXT AMT    Automatic
# 3     2017 Hyundai Grand i10  1.2 Kappa Sportz Option AT    Automatic
# 4         2016 Datsun RediGO                           S       Manual
# ...                      ...                         ...          ...
# 1731      2012 Maruti Ertiga                         VDI       Manual
# 1732    2019 Mahindra XUV500                          W7       Manual
# 1733  2018 Hyundai Grand i10  1.2 Kappa Sportz Option AT    Automatic
# 1734          2011 Ford Figo                  Diesel ZXI       Manual
# 1735     2011 Chevrolet Beat                          LT       Manual
#
#              Owner     KiloMeter    Fuel Year_of_purchase   Location  \
# ...

# %%
df1.to_csv("Banglore_data")

# %%
driver.close()

# %%
url4='https://www.cardekho.com/used-cars+in+mumbai'
driver.get(url4)

# %%
Brand=[]
Varient=[]
KM=[]
Fuel=[]
Transmission=[]
Price=[]
Location=[]

for i in driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/a'):
    Brand.append(i.text)
    



for i in driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/div[1]'):
    Varient.append(i.text)



for i in driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/div/span[1]'):
    KM.append(i.text)






for i in driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/div/span[2]'):
    Fuel.append(i.text)


for i in driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/div/span[3]'):
    Transmission.append(i.text)



for i in driver.find_elements_by_xpath('//div[@class="gsc_col-xs-5 text-right price"]/span'):
    Price.append(i.text)





for i in driver.find_elements_by_xpath('//div[@class="cityIcon"]'):
    try:
        Location.append(i.text)
    except:
        Location.append("--")



print("Location counts:-" ,len(Location))

print("Transmission Counts:-",  len(Transmission))
print("Fuel counts:-" , len(Fuel))   

print("KM counts:-" , len(KM))
print("Price counts:-",   len(Price))
print("Varient counts:-" ,  len(Varient))

print("Brand counts:- ",    len(Brand))
# Out:
# Location counts:- 1347
# Transmission Counts:- 2075
# Fuel counts:- 2075
# KM counts:- 2075
# Price counts:- 2075
# Varient counts:- 2075
# Brand counts:-  2075

# %%
loc10 = []
loc10.extend(["nan" for i in range(728)])
#loc10
Location.extend(loc10)
len(Location)
# Out:
# 2075

# %%
urls4=[]
for i in driver.find_elements_by_xpath('//div[@class="gsc_col-xs-7  carsName"]/a'):
    urls4.append(i.get_attribute('href'))

# %%
len(urls4)
# Out:
# 2075

# %%
Owner = []
Year_of_purchase = []

for i in urls4:
    driver.get(i)
    time.sleep(3)
    
    try:
        owner= driver.find_element_by_xpath('//li[@class="gsc_col-xs-6"][4]/div/div[1]')
        Owner.append(owner.text)
    except:
        Owner.append("--")
    
    try:
        year= driver.find_element_by_xpath('//li[@class="gsc_col-xs-6"][1]/div/div[1]')
        Year_of_purchase.append(year.text)
    except:
        Year_of_purchase.append("--")

# %%
len(Owner)
# Out:
# 2075

# %%
len(Year_of_purchase)
# Out:
# 2075

# %%
df1 = pd.DataFrame({})
df1["Brand"] = Brand
df1["Varient"] = Varient
df1["Transmission"] = Transmission
df1["Owner"] = Owner
df1["KiloMeter"] = KM
df1["Fuel"] = Fuel
df1["Year_of_purchase"] = Year_of_purchase
df1["Location"] = Location
df1["Price"] = Price


df1
# Out:
#                         Brand              Varient Transmission         Owner  \
# 0           2018 Renault KWID     1.0 RXT AMT BSIV    Automatic            --
# 1         2020 Maruti Celerio     VXI AMT Optional    Automatic            --
# 2        2017 Volkswagen Polo     1.2 MPI Highline       Manual            --
# 3            2017 Hyundai i20  1.2 Magna Executive       Manual            --
# 4     2014 Maruti Swift Dzire                  VXI       Manual            --
# ...                       ...                  ...          ...           ...
# 2070             2008 Audi Q7      3.0 TDI quattro    Automatic  Second Owner
# 2071       2015 Honda Mobilio            RS i-DTEC       Manual   First Owner
# 2072             2017 Audi A3  35 TDI Premium Plus    Automatic   First Owner
# 2073      2018 Maruti Wagon R              AMT VXI    Automatic   First Owner
# 2074       2016 Maruti Ertiga        SHVS ZDI Plus       Manual   First Owner
#
# ...

# %%
df1.to_csv("Mumbai_data")

# %%
driver.close()

# %%
df2=pd.read_csv("Ahmadabad_data")
df2
# Out:
#      Unnamed: 0                   Brand                     Varient  \
# 0             0        2016 Maruti Eeco            5 Seater AC BSIV
# 1             1   2018 Volkswagen Vento            1.5 TDI Highline
# 2             2        2017 Honda Amaze             S Option i-VTEC
# 3             3         2018 Honda City                    i-VTEC V
# 4             4     2014 Maruti Wagon R                         VXI
# ..          ...                     ...                         ...
# 532         532         2012 Maruti SX4                         VDI
# 533         533      2012 Maruti Ertiga                         LDI
# 534         534    2013 Mahindra Quanto                          C8
# 535         535  2018 Hyundai Grand i10  1.2 Kappa Sportz Option AT
# 536         536   2013 Mahindra Scorpio                 SLE 7S BSIV
#
#     Transmission         Owner     KiloMeter    Fuel Year_of_purchase  \
# 0         Manual            --    45,347 kms  Petrol               --
# ...

# %%
df3=pd.read_csv("Banglore_data")
df3
# Out:
#       Unnamed: 0                   Brand                     Varient  \
# 0              0        2013 Hyundai i10                      Sportz
# 1              1        2011 Hyundai i10                      Sportz
# 2              2       2018 Renault KWID                 1.0 RXT AMT
# 3              3  2017 Hyundai Grand i10  1.2 Kappa Sportz Option AT
# 4              4      2016 Datsun RediGO                           S
# ...          ...                     ...                         ...
# 1731        1731      2012 Maruti Ertiga                         VDI
# 1732        1732    2019 Mahindra XUV500                          W7
# 1733        1733  2018 Hyundai Grand i10  1.2 Kappa Sportz Option AT
# 1734        1734          2011 Ford Figo                  Diesel ZXI
# 1735        1735     2011 Chevrolet Beat                          LT
#
#      Transmission         Owner     KiloMeter    Fuel Year_of_purchase  \
# ...

# %%
df4=pd.read_csv("Mumbai_data")
df4
# Out:
#       Unnamed: 0                    Brand              Varient Transmission  \
# 0              0        2018 Renault KWID     1.0 RXT AMT BSIV    Automatic
# 1              1      2020 Maruti Celerio     VXI AMT Optional    Automatic
# 2              2     2017 Volkswagen Polo     1.2 MPI Highline       Manual
# 3              3         2017 Hyundai i20  1.2 Magna Executive       Manual
# 4              4  2014 Maruti Swift Dzire                  VXI       Manual
# ...          ...                      ...                  ...          ...
# 2070        2070             2008 Audi Q7      3.0 TDI quattro    Automatic
# 2071        2071       2015 Honda Mobilio            RS i-DTEC       Manual
# 2072        2072             2017 Audi A3  35 TDI Premium Plus    Automatic
# 2073        2073      2018 Maruti Wagon R              AMT VXI    Automatic
# 2074        2074       2016 Maruti Ertiga        SHVS ZDI Plus       Manual
#
# ...

# %%
df5=pd.read_csv("Pune_data")
df5
# Out:
#       Unnamed: 0                      Brand                 Varient  \
# 0              0           2020 Honda Amaze               VX Petrol
# 1              1            2015 Honda Jazz            1.5 V i DTEC
# 2              2      2020 Maruti Celerio X                 AMT ZXI
# 3              3  2018 Maruti Vitara Brezza                 ZDi AMT
# 4              4     2015 Hyundai Grand i10                 AT Asta
# ...          ...                        ...                     ...
# 1140        1140         2013 Skoda Octavia     Ambition 1.8 TSI AT
# 1141        1141          2015 Skoda Superb  Elegance 2.0 TDI CR AT
# 1142        1142         2009 Toyota Innova   2.5 V Diesel 8-seater
# 1143        1143           2011 Maruti Alto                     LXi
# 1144        1144         2015 Hyundai Verna       1.6 VTVT S Option
#
#      Transmission         Owner     KiloMeter    Fuel Year_of_purchase  \
# 0          Manual            --    12,887 kms  Petrol               --
# ...

# %%
dfn=df2.append(df3, ignore_index=True)
dfn
# Out:
#       Unnamed: 0                   Brand                     Varient  \
# 0              0        2016 Maruti Eeco            5 Seater AC BSIV
# 1              1   2018 Volkswagen Vento            1.5 TDI Highline
# 2              2        2017 Honda Amaze             S Option i-VTEC
# 3              3         2018 Honda City                    i-VTEC V
# 4              4     2014 Maruti Wagon R                         VXI
# ...          ...                     ...                         ...
# 2268        1731      2012 Maruti Ertiga                         VDI
# 2269        1732    2019 Mahindra XUV500                          W7
# 2270        1733  2018 Hyundai Grand i10  1.2 Kappa Sportz Option AT
# 2271        1734          2011 Ford Figo                  Diesel ZXI
# 2272        1735     2011 Chevrolet Beat                          LT
#
#      Transmission         Owner     KiloMeter    Fuel Year_of_purchase  \
# ...

# %%
dfn1=dfn.append(df4, ignore_index=True)
dfn1
# Out:
#       Unnamed: 0                  Brand              Varient Transmission  \
# 0              0       2016 Maruti Eeco     5 Seater AC BSIV       Manual
# 1              1  2018 Volkswagen Vento     1.5 TDI Highline       Manual
# 2              2       2017 Honda Amaze      S Option i-VTEC       Manual
# 3              3        2018 Honda City             i-VTEC V       Manual
# 4              4    2014 Maruti Wagon R                  VXI       Manual
# ...          ...                    ...                  ...          ...
# 4343        2070           2008 Audi Q7      3.0 TDI quattro    Automatic
# 4344        2071     2015 Honda Mobilio            RS i-DTEC       Manual
# 4345        2072           2017 Audi A3  35 TDI Premium Plus    Automatic
# 4346        2073    2018 Maruti Wagon R              AMT VXI    Automatic
# 4347        2074     2016 Maruti Ertiga        SHVS ZDI Plus       Manual
#
#              Owner     KiloMeter    Fuel Year_of_purchase   Location  \
# ...

# %%
dfn2=dfn1.append(df5, ignore_index=True)
dfn2
# Out:
#       Unnamed: 0                  Brand                 Varient Transmission  \
# 0              0       2016 Maruti Eeco        5 Seater AC BSIV       Manual
# 1              1  2018 Volkswagen Vento        1.5 TDI Highline       Manual
# 2              2       2017 Honda Amaze         S Option i-VTEC       Manual
# 3              3        2018 Honda City                i-VTEC V       Manual
# 4              4    2014 Maruti Wagon R                     VXI       Manual
# ...          ...                    ...                     ...          ...
# 5488        1140     2013 Skoda Octavia     Ambition 1.8 TSI AT    Automatic
# 5489        1141      2015 Skoda Superb  Elegance 2.0 TDI CR AT    Automatic
# 5490        1142     2009 Toyota Innova   2.5 V Diesel 8-seater       Manual
# 5491        1143       2011 Maruti Alto                     LXi       Manual
# 5492        1144     2015 Hyundai Verna       1.6 VTVT S Option       Manual
#
# ...

# %%
file_name = 'car_price_data.xlsx'
dfn2.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.
